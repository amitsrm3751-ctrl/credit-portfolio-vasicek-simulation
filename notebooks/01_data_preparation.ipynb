# %% [markdown]
# # Data Preparation – PD Model
#
# This notebook performs the data preparation stage for the Probability of Default (PD) modelling project.
#
# Steps performed:
# 1. Load and inspect LendingClub loan dataset
# 2. Define default variable
# 3. Filter relevant loan statuses
# 4. Feature engineering (credit history length, employment length, etc.)
# 5. Handle missing values with indicator variables
# 6. Treat outliers using winsorization
# 7. Remove leakage variables
#
# The cleaned dataset will be used in the next stage: Variable Diagnostics.

# %%
## importing the required libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# > **Dataset note:** Download the LendingClub loan dataset and place it at
# > `data/raw/loan_data.csv` relative to the project root before running this notebook.
# > The raw file is not included in the repository due to GitHub file size limits.

# %%
df = pd.read_csv('../data/raw/loan_data.csv', index_col=0, low_memory=False)

# %% [markdown]
# ## Dataset Overview
#
# The Lending Club dataset contains retail loan-level information including:
#
# - Borrower characteristics
# - Loan structure details
# - Repayment and recovery information
# - Loan status
#
# This step focuses on:
#
# 1. Inspecting dataset structure
# 2. Understanding loan status distribution
# 3. Preparing data for PD modelling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438697 non-null  object
#  11  emp_length                   445277 non-null  object
# ...

# %% [markdown]
# ## Initial Data Type Observations
#
# After inspecting the dataset using df.info(), the following columns require type correction or cleaning:
#
# - `term` → currently object; should be numeric (loan term in months)
# - `emp_length` → object; requires cleaning and numeric mapping
# - `pymnt_plan` → categorical (binary)
# - `earliest_cr_line` → object; should be converted to datetime
# - `issue_d` → object; should be converted to datetime
#
# These transformations are necessary for proper modelling and feature engineering.

# %% [markdown]
# ## Filtering Resolved Loans
#
# For Probability of Default (PD) modelling, only loans with final outcomes are considered.
#
# Included:
# - Fully Paid
# - Charged Off
#
# Excluded:
# - Current (active loans)
#
# This ensures that the target variable represents observed default behaviour.

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Current                                                224226
# Fully Paid                                             184739
# Charged Off                                             42475
# Late (31-120 days)                                       6900
# In Grace Period                                          3146
# Does not meet the credit policy. Status:Fully Paid       1988
# Late (16-30 days)                                        1218
# Default                                                   832
# Does not meet the credit policy. Status:Charged Off       761
# Name: count, dtype: int64

# %% [markdown]
# ## Defining Modelling Population
#
# For PD modelling, only loans with resolved outcomes are included.
#
# Default =
# - Charged Off
# - Default
# - Does not meet credit policy: Status: Charged Off
#
# Non-default =
# - Fully Paid
# - Does not meet credit policy: Status: Fully Paid
#
# Unresolved loan states (Current, Late, Grace Period) are excluded.
# Also, creating a loan_data dataframe a copy of df to protect the raw data

# %%
default_status = [
    'Charged Off',
    'Default',
    'Does not meet the credit policy. Status:Charged Off'
]

non_default_status = [
    'Fully Paid',
    'Does not meet the credit policy. Status:Fully Paid'
]
loan_data = df[df['loan_status'].isin(default_status + non_default_status)].copy()

# %%
loan_data['loan_status'].value_counts()/loan_data['loan_status'].count()
# Out:
# loan_status
# Fully Paid                                             0.800446
# Charged Off                                            0.184038
# Does not meet the credit policy. Status:Fully Paid     0.008614
# Default                                                0.003605
# Does not meet the credit policy. Status:Charged Off    0.003297
# Name: count, dtype: float64

# %%
loan_data['default'] = np.where(
    loan_data['loan_status'].isin(default_status),
    1,
    0
)

# %%
loan_data.shape
loan_data['default'].mean()
loan_data['default'].value_counts()
# Out:
# default
# 0    186727
# 1     44068
# Name: count, dtype: int64

# %%
loan_data.dtypes.value_counts()
# Out:
# float64    46
# object     22
# int64       6
# int32       1
# Name: count, dtype: int64

# %% [markdown]
# ### Inspecting Object Variables
#
# Before transforming object variables, we need to understand their nature.
#
# Object columns can represent:
#
# Numeric values stored as text (e.g., "36 months")
#
# Ordered categories (e.g., grade, emp_length)
#
# Nominal categories (e.g., home_ownership)
#
# High-cardinality categorical variables (e.g., purpose)
#
# Irrelevant identifiers (e.g., id, url)

# %%
loan_data.select_dtypes(include = 'object').columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
#        'next_pymnt_d', 'last_credit_pull_d', 'application_type'],
#       dtype='object')

# %% [markdown]
# ## Transforming Object Variables to Numeric Format

# %%
loan_data['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
loan_data['term_month'] = loan_data['term'].str.replace(r'[^0-9]','',regex=True)
loan_data['term_month'] = pd.to_numeric(loan_data['term_month'])

# %%
type(loan_data['term_month'][0])
# Out:
# numpy.int64

# %%
loan_data[['term', 'term_month']].head()
# Out:
#          term  term_month
# 0   36 months          36
# 1   60 months          60
# 2   36 months          36
# 3   36 months          36
# 5   36 months          36

# %%
loan_data['term_month'].isna().sum()
# Out:
# 0

# %%
loan_data['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '3 years', '9 years', '4 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years',
#        nan], dtype=object)

# %%
loan_data['emp_length_years'] = loan_data['emp_length'].str.strip()
loan_data['emp_length_years'] = loan_data['emp_length_years'].replace('< 1 year','0')
loan_data['emp_length_years'] = loan_data['emp_length_years'].str.replace(r'[^0-9]','',regex = True)
loan_data['emp_length_years'] = pd.to_numeric(loan_data['emp_length_years'])

# %%
type(loan_data['emp_length_years'][0])
# Out:
# numpy.float64

# %%
loan_data[['emp_length','emp_length_years']].head(10)
# Out:
#    emp_length  emp_length_years
# 0   10+ years              10.0
# 1    < 1 year               0.0
# 2   10+ years              10.0
# 3   10+ years              10.0
# 5     3 years               3.0
# 7     9 years               9.0
# 8     4 years               4.0
# 9    < 1 year               0.0
# 10    5 years               5.0
# 11  10+ years              10.0

# %%
type(loan_data['earliest_cr_line'][0])
# Out:
# str

# %% [markdown]
# ## Converting earliest_cr_line to Datetime Format
#
# The earliest_cr_line variable represents the borrower’s earliest reported credit line.
# Originally, this column is stored as a string (e.g., "Jan-85"), so it must be converted into a proper datetime format before performing any time-based calculations.
#
# We convert it using pd.to_datetime() with the appropriate format (%b-%y) to correctly interpret the month and year.
#
# This allows us to:
#
# Perform date arithmetic
#
# Derive account age
#
# Identify inconsistencies or anomalies in reported dates

# %%
loan_data['earliest_cr_line_date'] = pd.to_datetime(loan_data['earliest_cr_line'],format ='%b-%y')

# %%
type(loan_data['earliest_cr_line_date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
reference_date = pd.to_datetime('2016-12-01')

# %% [markdown]
# ## Creating months_since_earliest_cr_line
#
# To measure the borrower’s credit history length, we calculate the number of months between a fixed reference date and the borrower’s earliest credit line date.
#
# We use a reference date (2026-01-01) and compute:
#
# Months since earliest credit line =
# (Year difference × 12) + Month difference
#
# This creates a continuous numeric variable representing credit history length in months — an important predictor in credit risk modeling.
#
# Longer credit history generally indicates greater borrower stability and richer behavioral information.

# %%
loan_data['months_since_earliest_cr_line'] = ((reference_date.year - loan_data['earliest_cr_line_date'].dt.year) * 12 + 
                                            (reference_date.month - loan_data['earliest_cr_line_date'].dt.month))

# %%
loan_data['months_since_earliest_cr_line'].describe()
# Out:
# count    230766.000000
# mean        224.890582
# std          89.732723
# min        -624.000000
# 25%         171.000000
# 50%         211.000000
# 75%         267.000000
# max         575.000000
# Name: months_since_earliest_cr_line, dtype: float64

# %% [markdown]
# ## Identifying Data Anomalies (Negative Values)
#
# During exploratory checks, we observed negative values in months_since_earliest_cr_line.
#
# Negative values imply that some credit line dates are in the future relative to the reference date — which is logically impossible.
#
# This typically happens due to century interpretation issues (e.g., 2068 instead of 1968 when parsing two-digit years).
#
# We investigate these anomalies to ensure data integrity before modeling.

# %%
(loan_data.loc[loan_data['months_since_earliest_cr_line']< 0 , ['months_since_earliest_cr_line','earliest_cr_line_date']]).head(5)
# Out:
#       months_since_earliest_cr_line earliest_cr_line_date
# 1580                         -549.0            2062-09-01
# 1770                         -621.0            2068-09-01
# 3282                         -609.0            2067-09-01
# 3359                         -578.0            2065-02-01
# 3413                         -606.0            2067-06-01

# %% [markdown]
# ## Correcting Century Misinterpretation
#
# To correct the issue, we adjust any year that is greater than the reference year by subtracting 100 years.
#
# This effectively converts misinterpreted future dates (e.g., 2068) into their correct historical values (e.g., 1968).
#
# After correction, we recompute months_since_earliest_cr_line to ensure all values are positive and logically consistent.
#
# This step ensures accurate measurement of borrower credit history.

# %%
loan_data['earliest_cr_line_date'] = loan_data['earliest_cr_line_date'].apply( lambda x : x.replace(year = x.year - 100)
                                                                               if x.year > reference_date .year 
                                                                               else x )

# %%
loan_data['months_since_earliest_cr_line'] = ((reference_date.year - loan_data['earliest_cr_line_date'].dt.year) * 12 + 
                                            (reference_date.month - loan_data['earliest_cr_line_date'].dt.month))

# %%
loan_data['months_since_earliest_cr_line'].describe()
# Out:
# count    230766.000000
# mean        227.480218
# std          83.446374
# min          61.000000
# 25%         171.000000
# 50%         212.000000
# 75%         268.000000
# max         851.000000
# Name: months_since_earliest_cr_line, dtype: float64

# %% [markdown]
# ## Converting issue_d to Datetime Format
#
# The issue_d variable represents the loan issuance date and is originally stored as a string (e.g., "Jan-2015").
#
# To enable time-based calculations and portfolio vintage analysis, we convert this column to datetime format using pd.to_datetime().
#
# This transformation allows us to:
#
# Perform date arithmetic
#
# Calculate loan age
#
# Construct time-based risk features (e.g., months since issuance)
#
# Support vintage and cohort analysis
#
# Since the conversion logic is similar to the approach applied to earliest_cr_line, no additional anomaly corrections were required.

# %%
type(loan_data['issue_d'][0])
# Out:
# str

# %%
loan_data['issue_d'].describe()
# Out:
# count     230795
# unique        91
# top       Oct-14
# freq        8808
# Name: issue_d, dtype: object

# %%
loan_data['issue_date'] = pd.to_datetime(loan_data['issue_d'], format ='%b-%y', errors = 'coerce')

# %%
loan_data['months_since_issue_date'] = (
    (reference_date.year - loan_data['issue_date'].dt.year) * 12
    + (reference_date.month - loan_data['issue_date'].dt.month)
)

# %%
loan_data['months_since_issue_date'].describe()
# Out:
# count    230795.000000
# mean         46.077233
# std          16.483330
# min          24.000000
# 25%          34.000000
# 50%          43.000000
# 75%          54.000000
# max         114.000000
# Name: months_since_issue_date, dtype: float64

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230795 entries, 0 to 466283
# Data columns (total 81 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             230795 non-null  int64
#  1   member_id                      230795 non-null  int64
#  2   loan_amnt                      230795 non-null  int64
#  3   funded_amnt                    230795 non-null  int64
#  4   funded_amnt_inv                230795 non-null  float64
#  5   term                           230795 non-null  object
#  6   int_rate                       230795 non-null  float64
#  7   installment                    230795 non-null  float64
#  8   grade                          230795 non-null  object
#  9   sub_grade                      230795 non-null  object
#  10  emp_title                      217878 non-null  object
#  11  emp_length                     222040 non-null  object
# ...

# %% [markdown]
# ## Creating PD Modeling Dataset (Removing Post-Outcome Variables)
#
# To ensure proper Probability of Default (PD) modeling discipline, we restrict the feature set to variables available at loan origination.
#
# Post-outcome variables such as recoveries, payment amounts, and outstanding principal reflect events occurring after loan issuance and therefore introduce data leakage if used in PD estimation.
#
# To maintain modeling integrity:
#
# We retain the original dataset (loan_data_raw) for future LGD and EAD modeling.
#
# We create a separate dataset (loan_data_pd) containing only origination-time borrower characteristics.
#
# Post-default and cash flow variables are removed from the PD dataset.
#
# This separation ensures a clean modeling pipeline and aligns with industry best practices in credit risk modeling.

# %%
loan_data_raw = loan_data.copy()

# %%
loan_data_pd = loan_data.drop(columns=[
    'out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv',
    'total_rec_prncp','total_rec_int','total_rec_late_fee',
    'recoveries','collection_recovery_fee',
    'last_pymnt_d','last_pymnt_amnt',
    'next_pymnt_d','last_credit_pull_d','id','member_id','url',
    'desc','title','emp_title'
])

# %%
loan_data_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230795 entries, 0 to 466283
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   loan_amnt                      230795 non-null  int64
#  1   funded_amnt                    230795 non-null  int64
#  2   funded_amnt_inv                230795 non-null  float64
#  3   term                           230795 non-null  object
#  4   int_rate                       230795 non-null  float64
#  5   installment                    230795 non-null  float64
#  6   grade                          230795 non-null  object
#  7   sub_grade                      230795 non-null  object
#  8   emp_length                     222040 non-null  object
#  9   home_ownership                 230795 non-null  object
#  10  annual_inc                     230791 non-null  float64
#  11  verification_status            230795 non-null  object
# ...

# %% [markdown]
# ## Removing Columns with No Observations
#
# During structural inspection of the PD dataset, several variables were found to contain no non-null values (i.e., entirely missing).
#
# Columns with 100% missing values:
#
# Contain no predictive information
#
# Cannot be imputed meaningfully
#
# Increase model complexity unnecessarily
#
# Inflate memory usage
#
# To maintain a clean and efficient modeling dataset, these fully empty columns are removed prior to missing value treatment and feature engineering.
#
# This ensures that subsequent preprocessing steps focus only on variables with usable information.

# %%
# Identify columns with all values missing
empty_cols = loan_data_pd.columns[loan_data_pd.isna().all()]

# Drop fully empty columns
loan_data_pd = loan_data_pd.drop(columns=empty_cols)

# Confirm removal
loan_data_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230795 entries, 0 to 466283
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   loan_amnt                      230795 non-null  int64
#  1   funded_amnt                    230795 non-null  int64
#  2   funded_amnt_inv                230795 non-null  float64
#  3   term                           230795 non-null  object
#  4   int_rate                       230795 non-null  float64
#  5   installment                    230795 non-null  float64
#  6   grade                          230795 non-null  object
#  7   sub_grade                      230795 non-null  object
#  8   emp_length                     222040 non-null  object
#  9   home_ownership                 230795 non-null  object
#  10  annual_inc                     230791 non-null  float64
#  11  verification_status            230795 non-null  object
# ...

# %%
loan_data_pd.isna().mean().sort_values(ascending=False)
# Out:
# mths_since_last_record           0.880214
# mths_since_last_major_derog      0.825681
# mths_since_last_delinq           0.561901
# total_rev_hi_lim                 0.288026
# tot_cur_bal                      0.288026
# tot_coll_amt                     0.288026
# emp_length_years                 0.037934
# emp_length                       0.037934
# revol_util                       0.000979
# collections_12_mths_ex_med       0.000628
# open_acc                         0.000126
# total_acc                        0.000126
# inq_last_6mths                   0.000126
# earliest_cr_line                 0.000126
# delinq_2yrs                      0.000126
# acc_now_delinq                   0.000126
# earliest_cr_line_date            0.000126
# months_since_earliest_cr_line    0.000126
# pub_rec                          0.000126
# annual_inc                       0.000017
# policy_code                      0.000000
# application_type                 0.000000
# ...

# %% [markdown]
# ## Missing Value Assessment
#
# After computing the proportion of missing values for each variable, we categorize them based on the degree of missingness and economic interpretation.
#
# ### 🔴 High Missing (>80%)
#
# - `mths_since_last_record` (~88%)
# - `mths_since_last_major_derog` (~82%)
#
# These variables contain substantial missing values. In credit risk modelling, missingness in such variables often indicates absence of adverse credit events (e.g., no public records or major derogatory marks). Therefore, missing values may carry predictive information and should not be blindly imputed or removed.
#
# ---
#
# ### 🟠 Moderate Missing (~50–60%)
#
# - `mths_since_last_delinq` (~56%)
#
# This likely represents borrowers with no prior delinquency history. Missing values may therefore indicate lower credit risk. Treatment strategy should preserve this information (e.g., missing indicator + separate bin during WOE).
#
# ---
#
# ### 🟡 Moderate Missing (~28%)
#
# - `total_rev_hi_lim`
# - `tot_cur_bal`
# - `tot_coll_amt`
#
# These variables have meaningful coverage but require a structured imputation approach (e.g., median imputation or grouped imputation) before modelling.
#
# ---
#
# ### 🟢 Low Missing (<5%)
#
# - `emp_length_years` (~3.8%)
# - `revol_util` (<1%)
#
# These variables can be safely imputed using median or appropriate central tendency measures without materially distorting the distribution.
#
# ---
#
# ### Modelling Consideration
#
# In credit risk modelling, missing values are not assumed to be random by default.
# Where economically justified, missingness will be preserved as a potential risk signal during WOE binning.

# %% [markdown]
# # Exploratory Analysis & Feature Preparation for PD Modelling
#
# This section performs:
#
# 1. Missing value treatment strategy
# 2. Outlier detection and capping
# 3. Variable distribution analysis
# 4. Default rate relationship assessment
# 5. Preparation for WOE binning
#
# The objective is to construct a stable and interpretable feature set for Probability of Default modelling.

# %% [markdown]
# ## Selected Candidate Variables
#
# Based on economic intuition and modelling relevance, the following variables are selected for further analysis:
#
# ### Numerical Variables
# - total_rev_hi_lim
# - annual_inc
# - months_since_earliest_cr_line
# - acc_now_delinq
# - total_acc
# - pub_rec
# - open_acc
# - inq_last_6mths
# - delinq_2yrs
# - emp_length_years
#
# ### Categorical Variables
# - grade
# - sub_grade
# - home_ownership
# - verification_status
# - purpose
# - addr_state
# - initial_list_status

# %% [markdown]
# ## Missing Value Treatment Strategy
#
# In credit risk modelling, missing values are not assumed to be random by default.
# Missingness may contain economic meaning and therefore must be handled carefully.
#
# Variables are grouped based on:
#
# 1. Economic interpretation of missingness
# 2. Percentage of missing values
# 3. Suitability for imputation vs. separate risk signalling
#
# The treatment strategy is defined below.

# %%
missing_summary = (
    loan_data_pd.isna()
    .mean()
    .sort_values(ascending=False)
    .to_frame(name='missing_pct')
)

missing_summary
# Out:
#                                missing_pct
# mths_since_last_record            0.880214
# mths_since_last_major_derog       0.825681
# mths_since_last_delinq            0.561901
# total_rev_hi_lim                  0.288026
# tot_cur_bal                       0.288026
# tot_coll_amt                      0.288026
# emp_length_years                  0.037934
# emp_length                        0.037934
# revol_util                        0.000979
# collections_12_mths_ex_med        0.000628
# open_acc                          0.000126
# total_acc                         0.000126
# inq_last_6mths                    0.000126
# earliest_cr_line                  0.000126
# delinq_2yrs                       0.000126
# acc_now_delinq                    0.000126
# earliest_cr_line_date             0.000126
# months_since_earliest_cr_line     0.000126
# pub_rec                           0.000126
# annual_inc                        0.000017
# policy_code                       0.000000
# ...

# %%
loan_data_pd['mths_since_last_delinq_missing'] = loan_data_pd['mths_since_last_delinq'].isna().astype(int)
loan_data_pd['mths_since_last_delinq'] = loan_data_pd['mths_since_last_delinq'].fillna(999)

# %%
# Missing indicator
loan_data_pd['annual_inc_missing'] = loan_data_pd['annual_inc'].isna().astype(int)

# Median imputation
loan_data_pd['annual_inc'] = loan_data_pd['annual_inc'].fillna(
    loan_data_pd['annual_inc'].median()
)

# %%
loan_data_pd['annual_inc'].isnull().sum()
# Out:
# 0

# %%
loan_data_pd['months_since_earliest_cr_line'].isnull().sum()
# Out:
# 29

# %%
# Compute minimum observed value (excluding NaN)
min_value = loan_data_pd['months_since_earliest_cr_line'].min()

# Impute missing values with minimum observed value
loan_data_pd['months_since_earliest_cr_line'] = (
    loan_data_pd['months_since_earliest_cr_line']
    .fillna(min_value)
)

# Verify
loan_data_pd['months_since_earliest_cr_line'].isnull().sum()
# Out:
# 0

# %%
loan_data_pd['months_since_earliest_cr_line'].isnull().sum()
# Out:
# 0

# %%
loan_data_pd['acc_now_delinq'].isnull().sum()
# Out:
# 29

# %%
loan_data_pd['acc_now_delinq'] = loan_data_pd['acc_now_delinq'].fillna(0)

# %%
loan_data_pd['acc_now_delinq'].isnull().sum()
# Out:
# 0

# %%
loan_data_pd['total_acc'].isnull().sum()
# Out:
# 29

# %%
min_value = loan_data_pd['total_acc'].min()
loan_data_pd['total_acc'] = loan_data_pd['total_acc'].fillna(min_value)

# %%
loan_data_pd['total_acc'].isnull().sum()
# Out:
# 0

# %%
loan_data_pd['pub_rec'].value_counts().sort_index()
loan_data_pd.groupby('pub_rec')['default'].mean()
# Out:
# pub_rec
# 0.0     0.189936
# 1.0     0.196709
# 2.0     0.219014
# 3.0     0.187146
# 4.0     0.248485
# 5.0     0.265823
# 6.0     0.228571
# 7.0     0.312500
# 8.0     0.000000
# 9.0     0.400000
# 10.0    0.000000
# 11.0    0.000000
# Name: default, dtype: float64

# %%
loan_data_pd['pub_rec'] = loan_data_pd['pub_rec'].fillna(0)

# %%
cols = ['open_acc', 'inq_last_6mths','delinq_2yrs','emp_length_years']
loan_data_pd[cols].isnull().sum()
# Out:
# open_acc              29
# inq_last_6mths        29
# delinq_2yrs           29
# emp_length_years    8755
# dtype: int64

# %%
loan_data_pd.groupby(
    loan_data_pd['emp_length_years'].isna()
)['default'].mean()
# Out:
# emp_length_years
# False    0.187727
# True     0.272416
# Name: default, dtype: float64

# %%
loan_data_pd['emp_length_missing'] = (
    loan_data_pd['emp_length_years'].isna().astype(int)
)

loan_data_pd['emp_length_years'] = loan_data_pd['emp_length_years'].fillna(
    loan_data_pd['emp_length_years'].median()
)

# %%
min_open = loan_data_pd['open_acc'].min()
loan_data_pd['open_acc'] = loan_data_pd['open_acc'].fillna(min_open)

# %%
loan_data_pd['delinq_2yrs'] = loan_data_pd['delinq_2yrs'].fillna(0)

# %%
loan_data_pd['inq_last_6mths'] = loan_data_pd['inq_last_6mths'].fillna(0)

# %%
loan_data_pd[['open_acc','inq_last_6mths','delinq_2yrs','emp_length_years']].isnull().sum()
# Out:
# open_acc            0
# inq_last_6mths      0
# delinq_2yrs         0
# emp_length_years    0
# dtype: int64

# %% [markdown]
# ## Missing Value Treatment – Final Implementation Summary
#
# Missing values were handled using a structured, economically consistent framework suitable for PD modelling.
#
# Treatment decisions were based on:
#
# - Economic interpretation of each variable
# - Proportion of missing values
# - Observed default rate behaviour
# - Logical consistency of the credit dataset
#
# ---
#
# ### 1. Behavioural Variable
#
# **mths_since_last_delinq**
# - Missing values may indicate no recent delinquency.
# - Created a missing indicator variable.
# - Imputed missing values using a large placeholder value (999) to preserve ordering.
#
# ---
#
# ### 2. Continuous Income Variable
#
# **annual_inc**
# - Moderate skewness expected.
# - Created missing indicator variable.
# - Imputed using median value to ensure robustness against outliers.
#
# ---
#
# ### 3. Credit History Length
#
# **months_since_earliest_cr_line**
# - Very small missing proportion (<0.02%).
# - Zero would be economically inconsistent.
# - Imputed using minimum observed value to preserve logical ordering.
#
# ---
#
# ### 4. Account Count Variables
#
# **total_acc**
# - Very small missing proportion.
# - Borrower must have at least one tradeline.
# - Imputed using minimum observed value.
#
# **open_acc**
# - Very small missing proportion.
# - Imputed using minimum observed value.
#
# ---
#
# ### 5. Recent Credit Behaviour Variables
#
# **inq_last_6mths**
# - Missing likely implies no recent credit inquiries.
# - Imputed with 0.
#
# **delinq_2yrs**
# - Missing likely implies no recent delinquencies.
# - Imputed with 0.
#
# **pub_rec**
# - Missing treated as 0.
# - Variable exhibits increasing default rate with higher values.
#
# ---
#
# ### 6. Employment Length
#
# **emp_length_years**
# - Moderate missing proportion (~3.8%).
# - Missing group exhibits materially higher default rate.
# - Created missing indicator variable.
# - Imputed using median value to retain distribution stability.
#
# ---
#
# ### Final Status
#
# All selected variables now contain no missing values.
#
# The dataset is structurally clean and ready for:
#
# - Outlier diagnostics
# - Variable distribution analysis
# - WOE binning preparation
# - Dummy variable creation
#
# This concludes the missing value treatment stage of the PD data preparation process.

# %%
num_cols = [
    'loan_amnt',
    'annual_inc',
    'int_rate',
    'installment',
    'dti',
    'revol_bal',
    'revol_util',
    'total_acc',
    'open_acc',
    'months_since_earliest_cr_line'
]

# %%
import matplotlib.pyplot as plt

for col in num_cols:
    plt.figure(figsize=(6,3))
    plt.boxplot(loan_data_pd[col], vert=False)
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
for col in num_cols:
    print("--------------------------------------------------")
    print(col)
    print("Median :", loan_data_pd[col].median())
    print("1%     :", loan_data_pd[col].quantile(0.01))
    print("99%    :", loan_data_pd[col].quantile(0.99))
# Out:
# --------------------------------------------------
# loan_amnt
# Median : 12000.0
# 1%     : 1500.0
# 99%    : 35000.0
# --------------------------------------------------
# annual_inc
# Median : 61920.0
# 1%     : 18000.0
# 99%    : 235000.0
# --------------------------------------------------
# int_rate
# Median : 13.65
# 1%     : 6.03
# 99%    : 24.7
# --------------------------------------------------
# installment
# Median : 363.85
# 1%     : 51.26
# 99%    : 1192.64
# --------------------------------------------------
# dti
# Median : 16.05
# 1%     : 1.18
# 99%    : 33.81
# --------------------------------------------------
# revol_bal
# Median : 10979.0
# 1%     : 54.940000000000055
# 99%    : 80631.21999999991
# --------------------------------------------------
# revol_util
# Median : 56.5
# 1%     : 0.5
# 99%    : 97.7
# --------------------------------------------------
# total_acc
# Median : 23.0
# 1%     : 5.0
# 99%    : 59.0
# ...

# %%
cols_to_cap = ['annual_inc', 'revol_bal', 'installment']

for col in cols_to_cap:
    lower = loan_data_pd[col].quantile(0.01)
    upper = loan_data_pd[col].quantile(0.99)
    loan_data_pd[col] = loan_data_pd[col].clip(lower, upper)

# %%
loan_data_pd.isnull().sum().sort_values(ascending=False)
# Out:
# mths_since_last_record            203149
# mths_since_last_major_derog       190563
# total_rev_hi_lim                   66475
# tot_coll_amt                       66475
# tot_cur_bal                        66475
# emp_length                          8755
# revol_util                           226
# collections_12_mths_ex_med           145
# earliest_cr_line_date                 29
# earliest_cr_line                      29
# months_since_earliest_cr_line          0
# annual_inc_missing                     0
# total_acc                              0
# initial_list_status                    0
# mths_since_last_delinq_missing         0
# policy_code                            0
# application_type                       0
# acc_now_delinq                         0
# months_since_issue_date                0
# issue_date                             0
# revol_bal                              0
# default                                0
# term_month                             0
# ...

# %%
loan_data_pd['mths_since_last_record_missing'] = \
    loan_data_pd['mths_since_last_record'].isna().astype(int)

loan_data_pd['mths_since_last_record'] = \
    loan_data_pd['mths_since_last_record'].fillna(999)

# %%
loan_data_pd['mths_since_last_major_derog_missing'] = \
    loan_data_pd['mths_since_last_major_derog'].isna().astype(int)

loan_data_pd['mths_since_last_major_derog'] = \
    loan_data_pd['mths_since_last_major_derog'].fillna(999)

# %%
loan_data_pd['tot_cur_bal_missing'] = \
    loan_data_pd['tot_cur_bal'].isna().astype(int)

loan_data_pd['tot_cur_bal'] = \
    loan_data_pd['tot_cur_bal'].fillna(
        loan_data_pd['tot_cur_bal'].median()
    )

# %%
loan_data_pd['total_rev_hi_lim_missing'] = \
    loan_data_pd['total_rev_hi_lim'].isna().astype(int)

loan_data_pd['total_rev_hi_lim'] = \
    loan_data_pd['total_rev_hi_lim'].fillna(
        loan_data_pd['total_rev_hi_lim'].median()
    )

# %%
loan_data_pd['tot_coll_amt_missing'] = \
    loan_data_pd['tot_coll_amt'].isna().astype(int)

loan_data_pd['tot_coll_amt'] = \
    loan_data_pd['tot_coll_amt'].fillna(
        loan_data_pd['tot_coll_amt'].median()
    )

# %%
loan_data_pd['revol_util'] = \
    loan_data_pd['revol_util'].fillna(0)

# %%
loan_data_pd['collections_12_mths_ex_med'] = \
    loan_data_pd['collections_12_mths_ex_med'].fillna(0)

# %%
loan_data_pd.describe()
# Out:
#            loan_amnt    funded_amnt  funded_amnt_inv       int_rate  \
# count  230795.000000  230795.000000    230795.000000  230795.000000
# mean    13412.187114   13365.295500     13232.910101      13.781770
# min       500.000000     500.000000         0.000000       5.420000
# 25%      7200.000000    7200.000000      7000.000000      10.740000
# 50%     12000.000000   12000.000000     11750.000000      13.650000
# 75%     18000.000000   18000.000000     18000.000000      16.400000
# max     35000.000000   35000.000000     35000.000000      26.060000
# std      8042.975786    8017.161601      8055.476489       4.368738
#
#          installment     annual_inc            dti    delinq_2yrs  \
# count  230795.000000  230795.000000  230795.000000  230795.000000
# mean      414.692100   70796.152850      16.348890       0.243272
# min        51.260000   18000.000000       0.000000       0.000000
# 25%       237.190000   45000.000000      10.640000       0.000000
# ...

# %%
loan_data_pd.isnull().sum()
# Out:
# loan_amnt                                 0
# funded_amnt                               0
# funded_amnt_inv                           0
# term                                      0
# int_rate                                  0
# installment                               0
# grade                                     0
# sub_grade                                 0
# emp_length                             8755
# home_ownership                            0
# annual_inc                                0
# verification_status                       0
# issue_d                                   0
# loan_status                               0
# pymnt_plan                                0
# purpose                                   0
# zip_code                                  0
# addr_state                                0
# dti                                       0
# delinq_2yrs                               0
# earliest_cr_line                         29
# ...

# %%
loan_data_pd['emp_length'].dtype
# Out:
# dtype('O')

# %%
loan_data_pd['emp_length'].head(10)
# Out:
# 0     10+ years
# 1      < 1 year
# 2     10+ years
# 3     10+ years
# 5       3 years
# 7       9 years
# 8       4 years
# 9      < 1 year
# 10      5 years
# 11    10+ years
# Name: emp_length, dtype: object

# %%
loan_data_pd.drop(columns=['emp_length'], inplace=True)

# %%
loan_data_pd['earliest_cr_line'].dtype
# Out:
# dtype('O')

# %%
loan_data_pd['earliest_cr_line_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
loan_data_pd.drop(columns=['earliest_cr_line'], inplace=True)
loan_data_pd.drop(columns=['earliest_cr_line_date'], inplace=True)

# %%
loan_data_pd.isnull().sum()
# Out:
# loan_amnt                              0
# funded_amnt                            0
# funded_amnt_inv                        0
# term                                   0
# int_rate                               0
# installment                            0
# grade                                  0
# sub_grade                              0
# home_ownership                         0
# annual_inc                             0
# verification_status                    0
# issue_d                                0
# loan_status                            0
# pymnt_plan                             0
# purpose                                0
# zip_code                               0
# addr_state                             0
# dti                                    0
# delinq_2yrs                            0
# inq_last_6mths                         0
# mths_since_last_delinq                 0
# mths_since_last_record                 0
# open_acc                               0
# ...

# %% [markdown]
# ## Data Preparation Summary
#
# The data preparation stage has been completed with structured and model-driven preprocessing decisions.
#
# ### 1. Missing Value Treatment
# - Structural missing variables (e.g., `mths_since_last_record`, `mths_since_last_major_derog`) were handled using:
#   - Missing indicator variables
#   - Imputation with a special value (999) to represent “event never occurred”
# - Moderately missing bureau variables (`tot_cur_bal`, `total_rev_hi_lim`, `tot_coll_amt`) were treated using:
#   - Missing indicator variables
#   - Median imputation
# - Small missing variables (`revol_util`, `collections_12_mths_ex_med`) were imputed using median or 0 where logically appropriate.
# - Employment length was converted to numeric (`emp_length_years`), missing flag created, and median imputed.
# - All missing values have been fully resolved.
#
# ### 2. Outlier Treatment
# - Outliers were inspected using boxplots.
# - Heavy right-tail variables (`annual_inc`, `revol_bal`, `installment`) were capped using 1%–99% percentile winsorization.
# - No observations were removed to preserve modelling integrity.
#
# ### 3. Feature Engineering & Cleanup
# - Converted raw date variables into numerical features:
#   - `months_since_earliest_cr_line`
#   - `months_since_issue_date`
# - Dropped raw date and redundant columns (`earliest_cr_line`, `earliest_cr_line_date`, `emp_length`).
# - Ensured dataset consistency and removed duplicate representations.
#
# ### 4. Final Sanity Checks
# - Verified no remaining missing values.
# - Confirmed clean distributions post outlier treatment.
# - Dataset is now stable and ready for WOE binning and IV analysis.
#
# Data preparation phase is complete.

# %%
loan_data_pd.shape
# Out:
# (230795, 50)

# %%
loan_data_pd.shape
loan_data_pd.head()
loan_data_pd.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# loan_amnt                      0
# term_month                     0
# initial_list_status            0
# collections_12_mths_ex_med     0
# mths_since_last_major_derog    0
# policy_code                    0
# application_type               0
# acc_now_delinq                 0
# tot_coll_amt                   0
# tot_cur_bal                    0
# dtype: int64

# %%
loan_data_pd['default'].value_counts(normalize=True)
# Out:
# default
# 0    0.80906
# 1    0.19094
# Name: proportion, dtype: float64

# %%
loan_data_pd.to_csv("../data/processed/loan_data_cleaned.csv", index=False)

# %% [markdown]
# ### Final Dataset
#
# The dataset has been cleaned and prepared for PD modelling.
# Missing values have been handled, leakage variables removed,
# and engineered features created.
#
# This dataset will be used in the next stage:
# Variable Diagnostics and Feature Analysis.
